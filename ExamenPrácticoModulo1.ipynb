# %% [markdown]
# # Caso práctico
#
# Dado un archivo que contiene en cada línea una palabra o conjunto de palabras seguido de un valor numérico, denominado **“sentimiento”**, y un conjunto de tweets, se pide calcular para cada tweet un valor denominado **“sentimiento del tweet”**, que se obtiene como la suma de los “sentimientos” de los términos que aparecen en el tweet.
#
# Obsérvese que:
# - Cada línea del fichero Tweets.txt contiene una cadena JSON.
# - No todas las líneas del archivo Tweets.txt contiene tweets.
# - Cada tweet es representado por una cadena en formato JSON, en la que el tweet es almacenado en la clave text
# - Aquellas palabras o conjunto de palabras que aparecen en un tweet, y no tengan un “sentimiento” asociado en el archivo, se contabilizarán como 0.
#
# Para procesar el archivo hay que tener en cuenta que cada palabra o conjunto de palabras están separadas de su valor mediante el carácter “\t”. El archivo podría almacenarse en un diccionario.
#
# ## Resultado
# Como resultado, se debe mostrar por pantalla un valor numérico en cada línea que represente el “sentimiento” de un tweet.
# No todos los tweets que se van a considerar tienen contenido, por lo que hay que filtrar aquellos que tienen de los que no tienen.
# El programa tendrá 2 parámetros de entrada: el archivo que contiene los sentimientos de los términos y el archivo que contiene los tweets. Estos parámetros se pueden leer como input desde el teclado, directamente en el código o como parámetros con sys.args.

# %% [markdown]
# ## Importante!
#
# El programa esta dividido en métodos para desagregar la funcionalidad en partes más pequeñas, para ejecutar el programa completo se debe ejecutar el método **`main()`** que está en el último bloque de este notebook.

# %%
from os.path import exists
def solicitar_archivos() :
    """
    Método que no recibe parámetros y retorna el path hacia los archivos solicitados
    previamente validada su existencia
    """
    path_tweets = ""
    while True :
        path_tweets = input("Ingresa el nombre del archivo que contengan los tweets o el path hacia el archivo: ")
        if exists(path_tweets) :
            break
        print("El archivo ingresado no existe")

    path_sentimientos = ""
    while True :
        path_sentimientos = input("Ingresa el nombre del archivo que contengan los sentimientos o el path hacia el archivo: ")
        if exists(path_sentimientos) :
            break
        print("El archivo ingresado no existe")
    
    return (path_tweets, path_sentimientos)

# %%
import json
def obtener_tweets(path, key_tweet) :
    """
    Método que recibe como parámetro la ubicación del archivo de tweets y el nombre del key que contiene el text
    del tweet en el diccionario. Retorna un array de str todos los textos de los tweets encontrados, el método ya filtra los tweets que no tienen texto
    """
    print("Leyendo tweets.. ")
    tweets = []
    try :
        with open(path, "r") as archivo_tweets :
            for linea in  archivo_tweets :
                toJson = json.loads(linea)
                if key_tweet in toJson :
                    tweets.append(toJson[key_tweet])
        print("Ok")
        return tweets;
    except Exception as e :
        raise Exception("Ocurrió un error al leer el archivo de tweets, verifique el formato del archivo")

# %%
def obtener_sentimientos(path) :
    """
    Método que recibe la ubicación del arhivo de sentimientos, lo procesa y devuelve un diccionario con cada
    palabra de como su key y el peso del sentimiento como su value
    """
    print("Leyendo sentimientos.. ")
    sentimientos = {}
    try :
        with open(path, "r") as archivo_sentimientos :
            for linea in archivo_sentimientos :
                termino, valor = linea.split("\t")
                sentimientos[termino] = int(valor)
        print("Ok")
        return sentimientos
    except Exception as e :
        print(e)
        raise Exception("Ocurrió un error al leer el archivo de sentimientos, verifique el formato del archivo")

# %%
import numpy as np
def analizar_sentimientos(tweets, sentimientos) :
    """
    Método que recibe los tweets en array y los sentimientos en diccionario ya procesados y calcula el peso de cada tweet, retorna un array de enteros con la suma total del tweet
    """
    print("Analizando sentimientos de los tweets... ")
    tweets_normalizados = [tweet.lower() for tweet in tweets]
    peso_sentimiento = [];
    for tweet in tweets_normalizados :
        palabras = tweet.split(" ")
        pesos = np.asarray([ sentimientos[palabra] for palabra in palabras if palabra in sentimientos ])
        peso_sentimiento.append(pesos.sum())
    return peso_sentimiento

# %%
def imprimir_tweet_con_sentimiento(tweets, pesos) :
    print("Imprimiendo resultados...")
    print(" ")
    for idx, tweet in enumerate(tweets) :
        print("EL SIGUIENTE TWEET:", tweet, "TIENE UN SENTIMIENTO ASOCIADO DE:", pesos[idx])

# %%
def imprimir_tweet_con_sentimiento_truncado(tweets, pesos) :
    print("Imprimiendo resultados...")
    print(" ")
    for idx, tweet in enumerate(tweets) :
        print("EL SIGUIENTE TWEET:", tweet[0:20] + "...", "TIENE UN SENTIMIENTO ASOCIADO DE:", pesos[idx])

# %%
import time
def main(imprimir_tweet_truncado = True) :
    """
    Método principal que debe ejecutarse para correr el programa
    """

    print("Iniciando el programa... ")
    print(" ")
    try:
        
        path_archivos = solicitar_archivos()
        tweets = obtener_tweets(path_archivos[0], "text")
        print("  ")
        start = time.time()
        sentimientos = obtener_sentimientos(path_archivos[1])
        print("  ")
        pesos = analizar_sentimientos(tweets, sentimientos)
        print(" ")
        if imprimir_tweet_truncado :
            imprimir_tweet_con_sentimiento_truncado(tweets, pesos)
        else :
            imprimir_tweet_con_sentimiento(tweets, pesos)
        print(" ")
        print("Ejecución terminada a los", time.time() - start, "segundos")
            
    except Exception as e :
        print(e)

# %%
# Sólo informativo, ejecutar si se desea ver la documentación de cada método
print("solicitar_archivos()", solicitar_archivos.__doc__)
print("main()", main.__doc__)
print("obtener_tweets()", obtener_tweets.__doc__)
print("obtener_sentimientos()", obtener_sentimientos.__doc__)
print("analizar_sentimientos()", analizar_sentimientos.__doc__)

# %%
# Ejecuta el programa completo
# El parámetro imprimir_tweet_truncado sirve para una mejor visualización al momento de imprimir, si se pasa False se imprimirá todo el tweet
main(imprimir_tweet_truncado=True)
# Out:
# Iniciando el programa...
#
# Leyendo tweets..
# Ok
#
# Leyendo sentimientos..
# Ok
#
# Analizando sentimientos de los tweets...
#
# Imprimiendo resultados...
#
# EL SIGUIENTE TWEET: @Brenamae_ I WHALE S... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @byunghns: 😭 I LO... TIENE UN SENTIMIENTO ASOCIADO DE: 6
# EL SIGUIENTE TWEET: que hdp maicon lo qu... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ドライ！！！！！！！！！！！！！！！！！... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @GossipRoomOff: S... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Dayannalozano_: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: الله أكبر الله أكبر ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: TWİTTER'I AKRABALAR ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @PINKBATHARRY: le... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @le_Parisien: Ebo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @hailee_danielsx I'm... TIENE UN SENTIMIENTO ASOCIADO DE: -3
# EL SIGUIENTE TWEET: You better believe y... TIENE UN SENTIMIENTO ASOCIADO DE: 5
# EL SIGUIENTE TWEET: RT @baileymac02: CAN... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ドラコ・マルフォイ　「闇の帝王が支配なさ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @reading_bot_: 마주... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @En7raaF69: عبودي... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Vince Staples so col... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Chinamiiii721
#
# 球児？... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: '... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: #AbrahamMateoEnCanal... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @AppIe_France mais n... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: http://t.co/Chp71M0u... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Nashgrier: Happy... TIENE UN SENTIMIENTO ASOCIADO DE: 9
# EL SIGUIENTE TWEET: I liked a @YouTube v... TIENE UN SENTIMIENTO ASOCIADO DE: 4
# EL SIGUIENTE TWEET: RT @KirkJTorrance: C... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: RT @NASA: Roiling fl... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 続編きたあああ　 #prismailly... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: "@jaureguisteam: VOU... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: http://t.co/EMQdW8bh... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @PBirdly: Just se... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Dr_alqarnee: لست... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Kıskancım canım ben,... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @disneywords: Dre... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: RT @Ste1nkopf: http:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @a7laahm85: أميرت... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Aurinth I think it'... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: http://t.co/mFdtyT81... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @elofwind 중소기업이라 잡무만... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: みーせてーみせてどーぉかーみせてうんとが... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: もうお昼の時間だね。話題は変わるよ。今日... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JackAllTimeLow: ... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: RT @SoldierrOfAllah:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @SingleJoCoffee I li... TIENE UN SENTIMIENTO ASOCIADO DE: 4
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @PointlessBlog: W... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Chancho 🐷🐷🐷 http://t... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Sovainikita: @Pa... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: قال صلى الله عليه وس... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 伊紙、先制アシストの長友をMOMに選出「... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: MUULHER SCRR %%%% PQ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: “@DJZeeti: twitpic a... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Positivamos: tud... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: xxx vids: Lovely chi... TIENE UN SENTIMIENTO ASOCIADO DE: 6
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Need to get this fre... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: Amaia necesito un ce... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: http://t.co/qlQZMzZ4... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: yo dough! why she hi... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Is this not the best... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: RT @briflubia: http:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ちょいまって日曜って今週の？... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: If only I could put ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Elvinelol: World... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @m199z: @Azooz201... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JChristofides: p... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @1k305: 💞۝💞۝💞💎➊ #... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Assunto nas aulas: 1... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: due #MTVEMA  #Nomina... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @s_r_n__
# せやん... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @FaizaMirza84: Dr... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: シラヌイだって38とかだからさぁ・・・... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @cthagod: I keep ... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: อยากกินบอนชอน อยากกิ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: -
# QUEIMAR A LINGUA N... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: @Raissawktkalex waoo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Скачала наконец то С... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: わけわからんｗｗｗｗｗ ( @ayaka... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 293... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @kiavess @ChilleDewd... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @ZhArNTikA_: naif... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @yuxki @zibakurei_bo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @chi_tanmama 浜松なうだよw... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Van Morrison - Glori... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: com.android.internal... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ขอเพิ่มเติมเกี่ยวกับ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @euhanjung: "@sal... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: Clothing &amp; Shoes... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @laercioSoficial:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @LFCFaisal: الى ا... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @aartic02: Victor... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Es imposible aguntar... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: "@utahjazz: Jeremy E... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Why waste you time o... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: Mgkin apa yg kau nak... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @PBirdly: Just se... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: أخت المعرس أول مايدخ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @T1DFU: @sunshine... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 『Mステ　スーパーライブ2013　嵐、A... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @connpost: #Milfo... TIENE UN SENTIMIENTO ASOCIADO DE: -3
# EL SIGUIENTE TWEET: Me mueeeeeeeeeeeeeee... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: グラードンとカイオーガの新特性つよそう... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @TheBestOfTumbIr:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @alkhaldi_ksa: #ق... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Я ничего не боюсь, п... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: "@PointlessBlog: Who... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Ur sick bud... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: دعاء الغضب:أعوذ بالل... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Dag 2 http://t.co/UU... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @la12tuittera @ameri... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Now playing: Gaby Ba... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Blunote.it | SVOLTA ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @nouriaaajxo: 👌 h... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @tweetpotweet @RTS_S... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: عمره ١١ سنة ويكتب : ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @mmez11: للمتواجد... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: やったー続編！... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @4qh3_ 1o3q8ieshi... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @mariam_63  entra ac... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Sneezing like hell... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: @Belu_Cervantes jaja... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ஙே என்னாச்சி பழசு வத... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: En el bus demos prio... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I just took a test w... TIENE UN SENTIMIENTO ASOCIADO DE: 0
# EL SIGUIENTE TWEET: RT @MaxiiPoli: Iara ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Louis_Tomlinson:... TIENE UN SENTIMIENTO ASOCIADO DE: 9
# EL SIGUIENTE TWEET: No trato de ser mejo... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @EsppeonzAguirre:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Almusaffer: بعض ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @ZodiacoHoy: #Sag... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Dodi_gigolo: Pin... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: うおおおおおおおお！！... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Like omg 😍😍😍... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: @Thiagoarruee Vannn?... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Говорят, сегодня  Де... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @onedirection: If... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @SemihKIZILTAN: F... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Mugsy4Fly LOL! But ... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: @Sarahcourcis ouai m... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @apuri_kamisama: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @_helloitsjo lmaoo o... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @dalidragibus1: C... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @m_alhtershi: أتم... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @1967denberi: Ala... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @theMotherhood Thx f... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @1435P: ⭕ المتواج... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Belen_Chaya jajaja ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: せっかくワンピース持ってきたから着ようか... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @World_Images_: C... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Arab_Panorama: ب... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @SoccerSeki824 まあ、そこ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ニルヴァーシュが２時をお伝え！... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @anooood1401 سلام... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: JUST AHHHHHH😍😍😍😍🙌😱😍😍... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @yuuna623815 え、なにしたん... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @CHlLDHOODRUINER:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @laercioSoficial:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @QO_500: - وَقَدْ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Ru_ru50 ill beat th... TIENE UN SENTIMIENTO ASOCIADO DE: -6
# EL SIGUIENTE TWEET: RT @sandratorensma: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @maamsalcatraz: C... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @missshosh4: اروع... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @laercioSoficial:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @jmfmoran: Qué bu... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: @smallyson REBECA ME... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @onlyxibest: @LvB... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: That's the downside ... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: Time going too fast.... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Müzik bitince bilgis... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Agustina bigote te q... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Sou apaixonada por g... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: İnsan bazen kendi şa... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @TomiMondolo8: So... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Yıllarca ıssız bir a... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: We’re very proud to ... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: Bazen hayatımı"canım... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: jaa siel on Käläkäri... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Turkey Strawberry Br... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @bufnewspreptalk:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @TanPajeras: Pobr... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: "@wordsporn: #wordsp... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Estas son las series... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Gracias rubia @Su_La... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: "@CMinIzuz:  Os dejo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I think I am going t... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Wrinkle in Time Late... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 中学のクラス対抗合唱大会みたいなやつで、... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Moda__Chicas: RT... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @kashiwaren0818 暇な日あ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @kirisoor おやすみなさい〜( ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Buenas buenas buenas... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: やったね3期うおおおおおおおおおおおおお... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Max_Maillots: Il... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @H109Z بحاول يعني D'... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @ChelseaBorrelli:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @yomaira98x dude u h... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: Tidakkk rosakk speak... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @PoetryPix: Retwe... TIENE UN SENTIMIENTO ASOCIADO DE: 6
# EL SIGUIENTE TWEET: RT @C_Rivers24: @Cal... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: @ren85247 うわ普通。やっぱST... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JaiBrooks1: #wel... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @vip_1h: ثلث الحك... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JosDice: 🚐➕🎧 htt... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: DroidDia prime. Top ... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: RT @gazoushu: なんだこのア... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Matemáticas, física.... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @lxmharuka // Yas th... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @if_eee この状況無理なので汗臭い... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @hosoku3: 胸が大きい人は... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @augusto_rando: S... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: RT @sosyalpencere: E... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @JessicaFappit and t... TIENE UN SENTIMIENTO ASOCIADO DE: 7
# EL SIGUIENTE TWEET: @thequintavious is u... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: @glenisa10 you may b... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Spartacat1 @Strykr9... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: RT @congresskatni: @... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @tvtelehit @barbarai... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @maji_yabai: 亜久津が... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @PointlessBlog me🙋... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @emmyrossum: The ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @gonullu35: İsviç... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Louis_Tomlinson:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @emreayazjj: Deme... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 1度だけグーフィー好きになりたての頃に長... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @_hopehopes: เกลี... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Ariana grande😍 http:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @MAMBRU17: Termin... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @apuri_kamisama: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 長財布（小銭入れあり）部門でこれがランク... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Paint the town this ... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: 昨日ストーカーに殺されかける夢見たんだけ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Thank god for the GR... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: Best person in the w... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: Lost my headphones ,... TIENE UN SENTIMIENTO ASOCIADO DE: -3
# EL SIGUIENTE TWEET: People at my school ... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: @Peeweezzy exactly w... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: things are hard... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: Me zanima, če bo kak... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: De inveja eu não mor... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @xJordaan37: Elle... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Fco__Arevalo ahhhh ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: No olvide nada, solo... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: اللهم اغفر لي ذنبي ،... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Aliciabissiri: C... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: RT@YouthH2O Whats on... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: غَربِل حبايبك بالغِي... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @RenoiDuVillage lol ... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: @jossi_ort  yo quier... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: http://t.co/Kd45G9FK... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 망명과 난민 무엇이 다를까?
#
# htt... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JackMuzik: La ge... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @AntonioFrench: A... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @fbjooohm: @AJApp... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ガソリン入れて帰るか... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: churros? kk... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 【時報】
# 2:00だよ〜... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I've harvested 1,134... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: いきなり美容院のイケメンからLINEきて... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @foofighters: htt... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @__CharmaineMG: B... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @adnan_oktar: Rad... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @_Lucas_Goulart cala... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: バベル
# 鉄格子を自在に用いり、人種・国籍... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JackMuzik: La ge... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: María Sharapova aseg... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Mo_nrm3: تاخذ من... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @MouthHugsAndA7X:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I took this preacher... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: Çünkü seninle konuşu... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: だめ、もう、辛い... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Even Johnny Depp kno... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I was busy being nak... TIENE UN SENTIMIENTO ASOCIADO DE: -6
# EL SIGUIENTE TWEET: @rihanna miss ya... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: Чернобелая моя жизнь... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 3期決定かーーーーーー... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Real shit http://t.c... TIENE UN SENTIMIENTO ASOCIADO DE: -4
# EL SIGUIENTE TWEET: RT @apuri_kamisama: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @vsfporr4_: essa ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @vamennow: ระวัง!... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: New Job: Job 10017 a... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: #RT If you Like.... ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: おいおい…
# 大丈夫なんすか... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: http://t.co/gMKVqXRi... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Caniiimm http://t.co... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ✔️ Parceria PJB: Vot... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Vamos a lavarlo por ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Es gracioso cuando a... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @anyii_1412 jajajjaj... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Oso_GlodUp: Lol ... TIENE UN SENTIMIENTO ASOCIADO DE: -5
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Frozen Girls Anna an... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @duygu_damar direnem... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: انت اي صف — 11 http:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 【定期】MMD動画師やってる夢蘭です(*... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I thought I would be... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: 純太！お誕生日おめでとう♪ ♬ ヾ(´︶... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: nuevo comienzo a mi ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @LeoQuotez: #Leo'... TIENE UN SENTIMIENTO ASOCIADO DE: 4
# EL SIGUIENTE TWEET: seu perfil foi visto... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: me re  juiiiiiiii... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @NRieraF: La bell... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: エロゲもせずになんとか乙女ゲーをやってや... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Nashgrier: Honey... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @m_d__ha I can't bel... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: #amigairmã #carasebo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @RottenTomatoes: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Haashleey MUNOCO.... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Nashgrier: New S... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @RISDAthletics: V... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @ToptapPlaych: เก... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: やっと半分とか(白目)... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Ce truc va me rendre... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ・.*♡L'Arc~en~Ciel♡*.... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @alecostajimenez:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Nashgrier: Good ... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: @SoyNovioDeTodas ¡En... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: "Acaba bu tweette ba... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @attitydisk mansdomi... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @1DUpdateBRA: Até... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @BieberAnnual: Re... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: (　＾ω＾ 三　＾ω＾　)ﾋｭﾝﾋｭﾝ ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @JeremiahTaylorr:... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: @makimaki_mama ┌(┌^q... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Being with you is li... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: Nicole Moudaber - In... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @Pplschamp2310 At th... TIENE UN SENTIMIENTO ASOCIADO DE: -2
# EL SIGUIENTE TWEET: Food &amp; Ryhmes fo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @ChochoMartinez1:... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: RT @omoro_ojisan: 【前... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @_ifr_: "اللهم لا... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 12/3/21@シソンヌじろう ルミネタ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @akatyan2: 突然大人の表... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @sandratorensma: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Mo_nrm3: تاخذ من... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Destiny初日で売り上げ5億ドルかよ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Recién veo ese mensa... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @nialls_lovexz @aMee... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @sergioaruizh: Lo... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 132... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @NourhanIsmail97 MH ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @TuiteiEmoticons:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @sekai_syogeki: 宮... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Ayed_Alosaimi: إ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: header ? 👀... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Después de 2 meses d... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Aula só 15:15 agora... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Meryem ile bir dedik... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: nasıl olurda???Hâla ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Hadi artık sen konuş... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: i don't know what to... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @BeyonceExplicit hel... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Seriously need some ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Metin Şentürk Twitte... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @BieberAnnual: 2 ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: La entrada perfecta ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @sonjimmons: Just... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @m_k_s_8: للمتواج... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Happy Birthday to Ro... TIENE UN SENTIMIENTO ASOCIADO DE: 10
# EL SIGUIENTE TWEET: @bakunyufujin
#
# オメーの... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: When she says the di... TIENE UN SENTIMIENTO ASOCIADO DE: -3
# EL SIGUIENTE TWEET: Günlük Rapor: 47 kiş... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Dear downstairs neig... TIENE UN SENTIMIENTO ASOCIADO DE: 6
# EL SIGUIENTE TWEET: RT @yungthanatos: "w... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @tab3na1: برمجيات... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Pose de viado, sem c... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: ただひとつの... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Odeio qnd esqueço de... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: lçklçl... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @miga_hisoka كلان كب... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Just hit some speed ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: #JAGNATION #X 238... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @gyak615: @pink 다... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: 【定期】霊夢！主人公補正とか許さん！だい... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: WHY DOES MADDIE NEED... TIENE UN SENTIMIENTO ASOCIADO DE: 4
# EL SIGUIENTE TWEET: RT @Nashgrier: Happy... TIENE UN SENTIMIENTO ASOCIADO DE: 9
# EL SIGUIENTE TWEET: RT @eglobalinfo: eGl... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: (デング熱で学外休めるかな…)... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @dantyre: #INBOUN... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: มัน00.01ละ อีควาย... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Jangan berubah hanya... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @FutboolFichajes:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @katyperry: Don't... TIENE UN SENTIMIENTO ASOCIADO DE: -1
# EL SIGUIENTE TWEET: http://t.co/tAUtZahe... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: I'm sure they were u... TIENE UN SENTIMIENTO ASOCIADO DE: 0
# EL SIGUIENTE TWEET: RT @Tarunvijay: Popu... TIENE UN SENTIMIENTO ASOCIADO DE: 4
# EL SIGUIENTE TWEET: RT @9GAG: My mood de... TIENE UN SENTIMIENTO ASOCIADO DE: 3
# EL SIGUIENTE TWEET: 368... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: @jeremiahtolbert @sa... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @fishnote: &lt;자산... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: http://t.co/lbtoxOp5... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @NKsubs: Leeteuk:... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: 【自動】おやすみるきーヾ(･ω･o)... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @Gabriele_Corno: ... TIENE UN SENTIMIENTO ASOCIADO DE: 1
# EL SIGUIENTE TWEET: @_mjodcx تمم... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: だめだ動けないなんてことだ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @BestofCancer: #C... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @gazoushu: なんだこのア... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @30vs09: FA) 슈가군 ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: A participar del Con... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: Just waking up in th... TIENE UN SENTIMIENTO ASOCIADO DE: 2
# EL SIGUIENTE TWEET: RT @ThisIsYourEvent:... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @temasparamujer: ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @BLEACHmei: BLEAC... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @hojimin31814: ไอ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @AL_shiratori: 【中... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: RT @shinparu0330: ぱる... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
# EL SIGUIENTE TWEET: FFC IP's Symbaloo - ... TIENE UN SENTIMIENTO ASOCIADO DE: 0.0
#
# Ejecución terminada a los 0.10018157958984375 segundos
